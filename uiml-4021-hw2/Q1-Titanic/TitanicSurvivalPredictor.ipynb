# %% [markdown]
# # Import Required Libraraies

# %%
import re
import numpy as np
import pandas as pd

# %% [markdown]
# # Read Data
# Read training and test data from specified path

# %%
train_data = pd.read_csv('train.csv')
test_data = pd.read_csv('test.csv')
# gender_sub = pd.read_csv('/kaggle/input/titanic/gender_submission.csv')

# %%
test_data.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %% [markdown]
# # Data Purification and Feature Engineering

# %% [markdown]
# ## Name
# ### Extract titles from names

# %%
train_data['Title'] = train_data['Name'].apply(lambda x: re.search(' ([A-Za-z]+)\.', x).group(1))
test_data['Title'] = test_data['Name'].apply(lambda x: re.search(' ([A-Za-z]+)\.', x).group(1))

# Display the unique titles
print(f'All unique titles in names (Train): {train_data["Title"].unique()}')
print(f'All unique titles in names (Test): {test_data["Title"].unique()}')
# Out:
# All unique titles in names (Train): ['Mr' 'Mrs' 'Miss' 'Master' 'Don' 'Rev' 'Dr' 'Mme' 'Ms' 'Major' 'Lady'
#  'Sir' 'Mlle' 'Col' 'Capt' 'Countess' 'Jonkheer']
# All unique titles in names (Test): ['Mr' 'Mrs' 'Miss' 'Master' 'Ms' 'Col' 'Rev' 'Dr' 'Dona']

# %% [markdown]
# ### Replace least repeated ones with 'Other' and with most common ones

# %%
# Train Data
train_data['Title'] = train_data['Title'].replace(['Lady', 'Countess', 'Capt', 'Col', 'Don', 'Dr','Major', 'Rev', 'Sir', 'Jonkheer', 'Dona'], 'Other')
train_data['Title'] = train_data['Title'].replace(['Mlle', 'Ms'], 'Miss')
train_data['Title'] = train_data['Title'].replace('Mme', 'Mrs')

# Test Data
test_data['Title'] = test_data['Title'].replace(['Lady', 'Countess', 'Capt', 'Col', 'Don', 'Dr','Major', 'Rev', 'Sir', 'Jonkheer', 'Dona'], 'Other')
test_data['Title'] = test_data['Title'].replace(['Mlle', 'Ms'], 'Miss')
test_data['Title'] = test_data['Title'].replace('Mme', 'Mrs')

# %%
print(f'Train Titles: {train_data["Title"].unique()}')
print(f'Test Titles: {test_data["Title"].unique()}')
# Out:
# Train Titles: ['Mr' 'Mrs' 'Miss' 'Master' 'Other']
# Test Titles: ['Mr' 'Mrs' 'Miss' 'Master' 'Other']

# %% [markdown]
# ### Drop Names

# %%
train_data = train_data.drop('Name', axis=1)
test_data = test_data.drop('Name', axis=1)

# %% [markdown]
# ### Encode Titles

# %%
title_to_number = {'Mr': 0, 'Mrs': 1, 'Miss': 2, 'Master': 3, 'Other': 4}

train_data['Title'] = train_data['Title'].apply(lambda x: title_to_number[x])
test_data['Title'] = test_data['Title'].apply(lambda x: title_to_number[x])

# %% [markdown]
# ## Ticket
# ### Drop ticket columns

# %%
# Drop Ticket Column
train_data = train_data.drop('Ticket', axis=1)
test_data = test_data.drop('Ticket', axis=1)

# %% [markdown]
# ## Sex
# ### Convert sexes to 0s and 1s
# Label-encode the gender values

# %%
# Encode Sex
train_data['Sex'] = train_data['Sex'].replace({'male': 0, 'female': 1})
test_data['Sex'] = test_data['Sex'].replace({'male': 0, 'female': 1})
print(f'Number of distinct values for sex: {set(test_data["Sex"])}')
# Out:
# Number of distinct values for sex: {0, 1}

# %% [markdown]
# ## Cabin
# ### Extract letters from Cabins

# %%
train_data['Cabin'] = train_data['Cabin'].fillna("X")
print(train_data['Cabin'].str[0].unique())

test_data['Cabin'] = test_data['Cabin'].fillna("X")
print(test_data['Cabin'].str[0].unique())
# Out:
# ['X' 'C' 'E' 'G' 'D' 'A' 'B' 'F' 'T']
# ['X' 'B' 'E' 'A' 'C' 'D' 'F' 'G']

# %% [markdown]
# ### Encode letters

# %%
cabin_to_number = {'X': 0, 'A': 1, 'B': 2, 'C': 3, 'D': 4, 'E': 5, 'F': 6, 'G': 7, 'T': 8}

train_data['Cabin_Encoded'] = train_data['Cabin'].apply(lambda x: cabin_to_number[x[0]])
test_data['Cabin_Encoded'] = test_data['Cabin'].apply(lambda x: cabin_to_number[x[0]])

# %% [markdown]
# ### Drop Cabin Column

# %%
train_data = train_data.drop('Cabin', axis=1)
test_data = test_data.drop('Cabin', axis=1)

# %% [markdown]
# ## Embarked
# ### Fill Null values with 'S' (Most common one)

# %%
train_data['Embarked'].describe()

train_data['Embarked'] = train_data['Embarked'].fillna('S')
test_data['Embarked'] = test_data['Embarked'].fillna('S')

# %% [markdown]
# ### Encode Embarked Values

# %%
embark_to_number = {'S': 0, 'C': 1, 'Q': 2}

train_data['Embarked'] = train_data['Embarked'].apply(lambda x: embark_to_number[x])
test_data['Embarked'] = test_data['Embarked'].apply(lambda x: embark_to_number[x])

# %% [markdown]
# ## Age
# ### Fill null values of age with mean age of train set

# %%
mean_age = train_data['Age'].mean()

train_data['Age'] = train_data['Age'].fillna(mean_age)
test_data['Age'] = test_data['Age'].fillna(mean_age)

# %% [markdown]
# ### Convert ages to int

# %%
train_data['Age'] = train_data['Age'].astype(int)
test_data['Age'] = test_data['Age'].astype(int)

# %% [markdown]
# ## Fare

# %%
print(f'number of fare null values of train set: {train_data["Fare"].isna().sum()}')
print(f'number of fare null values of test set: {test_data["Fare"].isna().sum()}')
# Out:
# number of fare null values of train set: 0
# number of fare null values of test set: 1

# %% [markdown]
# ### Fill null values with mean fare

# %%
mean_fare = train_data['Fare'].mean()

train_data['Fare'] = train_data['Fare'].fillna(mean_fare)
test_data['Fare'] = test_data['Fare'].fillna(mean_fare)

# %% [markdown]
# ### Convert fares to ints

# %%
train_data['Fare'] = train_data['Fare'].astype(int)
test_data['Fare'] = test_data['Fare'].astype(int)

# %% [markdown]
# ## PassengerId (Train)
# ### Drop column

# %%
train_data = train_data.drop(['PassengerId'], axis=1)

# %% [markdown]
# ### Getting data ready

# %%
X_train = train_data.drop("Survived", axis=1)
Y_train = train_data["Survived"]
X_test  = test_data.drop("PassengerId", axis=1).copy()
testPassengerIds = test_data['PassengerId']

# %% [markdown]
# # Data Normalization
# Normalize both training and test data using z-score

# %%
for col in X_train.columns:
    train_column = X_train[col]
    test_column = X_test[col]
    
    mean_val = train_column.mean()
    std_val = train_column.std()
    
    X_train[col] = (train_column - mean_val) / std_val
    X_test[col] = (test_column - mean_val) / std_val

# %%
X_train.head()
# Out:
#      Pclass       Sex       Age     SibSp     Parch      Fare  Embarked  \
# 0  0.826913 -0.737281 -0.579719  0.432550 -0.473408 -0.498667 -0.568518
# 1 -1.565228  1.354813  0.649747  0.432550 -0.473408  0.788962  1.004617
# 2  0.826913  1.354813 -0.272352 -0.474279 -0.473408 -0.498667 -0.568518
# 3 -1.565228  1.354813  0.419222  0.432550 -0.473408  0.426816 -0.568518
# 4  0.826913 -0.737281  0.419222 -0.474279 -0.473408 -0.478548 -0.568518
#
#       Title  Cabin_Encoded
# 0 -0.738132      -0.488186
# 1  0.190788       1.397540
# 2  1.119709      -0.488186
# 3  0.190788       1.397540
# 4 -0.738132      -0.488186

# %%
X_test.head()
# Out:
#      Pclass       Sex       Age     SibSp     Parch      Fare  Embarked  \
# 0  0.826913 -0.737281  0.342381 -0.474279 -0.473408 -0.498667  2.577752
# 1  0.826913  1.354813  1.341322  0.432550 -0.473408 -0.498667 -0.568518
# 2 -0.369158 -0.737281  2.493947 -0.474279 -0.473408 -0.458429  2.577752
# 3  0.826913 -0.737281 -0.195511 -0.474279 -0.473408 -0.478548 -0.568518
# 4  0.826913  1.354813 -0.579719  0.432550  0.767199 -0.398071 -0.568518
#
#       Title  Cabin_Encoded
# 0 -0.738132      -0.488186
# 1  0.190788      -0.488186
# 2 -0.738132      -0.488186
# 3 -0.738132      -0.488186
# 4  0.190788      -0.488186

# %%
Y_train.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: Survived, dtype: int64

# %% [markdown]
# ## Separate cross validation set from train data
# Separate Cross Validation set from training set (5% of train data)

# %%
# Set the random seed for reproducibility
np.random.seed(42)

# Shuffle the data
shuffle_indices = np.random.permutation(len(X_train))
X_train_shuffled = X_train.values[shuffle_indices]
Y_train_shuffled = Y_train.values[shuffle_indices]

# Define the proportion of data to be allocated for cross-validation
val_split = 0.05

# Calculate the number of examples for the cross-validation set
num_val = int(val_split * len(X_train_shuffled))

# Split the data into training and cross-validation sets
X_train = X_train_shuffled[:-num_val]
Y_train = Y_train_shuffled[:-num_val]
X_val = X_train_shuffled[-num_val:]
Y_val = Y_train_shuffled[-num_val:]

# %% [markdown]
# # Logistic Regression
# This Python code defines a simple logistic regression class. The LogisticRegression class has methods for sigmoid activation, binary cross-entropy loss calculation, gradient descent optimization for parameter updates, training the model with a specified number of iterations and early stopping, and making predictions.

# %%
class LogisticRegression:
    def __init__(self, max_iterations=1000, learning_rate=0.01, decay=0.9, epsilon=1e-5):
        self.max_iterations = max_iterations
        self.learning_rate = learning_rate
        self.decay = decay
        self.epsilon = epsilon
        self.W = None
        self.b = None

        
    def sigmoid(self, z):
        a = 1 / (1 + np.exp(-z))
        return a

    
    def binary_cross_entropy(self, y_pred, y):
        epsilon = 1e-15
        y_pred = np.clip(y_pred, epsilon, 1 - epsilon)
        loss = -(y * np.log(y_pred) + (1 - y) * np.log(1 - y_pred)).mean()
        return loss

    
    def gradient_descent(self, X, y):
        m, n = X.shape

        dz = self.sigmoid(X.dot(self.W) + self.b) - y
        dw = np.dot(X.T, dz) / m
        db = np.sum(dz) / m

        return dw, db

    
    def fit(self, X, y):
        n_samples, n_features = X.shape

        self.W = np.random.randn(n_features) * 0.01
        self.b = 0
        previous_loss = np.inf
        lr = self.learning_rate

        for _ in range(self.max_iterations):
            # Calculate Gradients
            dw, db = self.gradient_descent(X, y)

            # Update Parameters
            self.W -= lr * dw
            self.b -= lr * db

            # Check for Early Stop
            current_loss = self.binary_cross_entropy(self.sigmoid(X.dot(self.W) + self.b), y)
            if np.abs(current_loss - previous_loss) < self.epsilon:
                print(f'Stopping Train at Iteration No.{_}')
                break

            previous_loss = current_loss
            lr *= self.decay

        print(f'Training Complete with Binary Cross Entropy Loss of {current_loss}')

        
    def predict(self, X):
        y_pred = self.sigmoid(np.dot(X, self.W) + self.b)
        return (y_pred >= 0.5).astype(int)

# %% [markdown]
# ## Check different hyperparameters
# Run different combination of hyper-paramters for testing performance on cross validation

# %%
max_iterations_values = [100, 200, 500, 1000]
learning_rate_values = [0.1, 0.5, 1.0, 1.5, 2.0, 2.5]
decay_values = [0.8, 0.85, 0.9, 0.92, 0.95, 0.99]
epsilon_values = [1e-5, 1e-10]

best_score = float('inf')
best_hyperparameters = None

for max_iterations in max_iterations_values:
    for learning_rate in learning_rate_values:
        for decay in decay_values:
            for epsilon in epsilon_values:
                lr_model_test = LogisticRegression(max_iterations, learning_rate, decay, epsilon)
                lr_model_test.fit(X_train, Y_train)

                # Evaluate the model on the validation set
                score = lr_model_test.binary_cross_entropy(lr_model_test.sigmoid(X_val.dot(lr_model_test.W) + lr_model_test.b), Y_val)

                # Check if the current combination of hyperparameters achieved a better score
                if score < best_score:
                    best_score = score
                    best_hyperparameters = (max_iterations, learning_rate, decay, epsilon)

print(f"Best Score: {best_score}")
print(f"Best Hyperparameters: {best_hyperparameters}")
# Out:
# Stopping Train at Iteration No.32
# Training Complete with Binary Cross Entropy Loss of 0.6210388537798901
# Stopping Train at Iteration No.84
# Training Complete with Binary Cross Entropy Loss of 0.6210408997841641
# Stopping Train at Iteration No.43
# Training Complete with Binary Cross Entropy Loss of 0.5999775885889115
# Training Complete with Binary Cross Entropy Loss of 0.6017772990111427
# Stopping Train at Iteration No.63
# Training Complete with Binary Cross Entropy Loss of 0.5690411853124714
# Training Complete with Binary Cross Entropy Loss of 0.5697301839083925
# Stopping Train at Iteration No.77
# Training Complete with Binary Cross Entropy Loss of 0.5542915439231705
# Training Complete with Binary Cross Entropy Loss of 0.5542965465780847
# Training Complete with Binary Cross Entropy Loss of 0.5205811452255429
# Training Complete with Binary Cross Entropy Loss of 0.5192544415441032
# Training Complete with Binary Cross Entropy Loss of 0.45735639074023704
# Training Complete with Binary Cross Entropy Loss of 0.45736832726451515
# Stopping Train at Iteration No.32
# Training Complete with Binary Cross Entropy Loss of 0.5003740513016921
# Stopping Train at Iteration No.84
# Training Complete with Binary Cross Entropy Loss of 0.5005814876674048
# Stopping Train at Iteration No.41
# Training Complete with Binary Cross Entropy Loss of 0.4829636033389977
# Training Complete with Binary Cross Entropy Loss of 0.4833583429757635
# Stopping Train at Iteration No.57
# Training Complete with Binary Cross Entropy Loss of 0.4649415489411398
# Training Complete with Binary Cross Entropy Loss of 0.46485592121895697
# Stopping Train at Iteration No.67
# Training Complete with Binary Cross Entropy Loss of 0.4573560407118237
# Training Complete with Binary Cross Entropy Loss of 0.4568852721428836
# Stopping Train at Iteration No.88
# Training Complete with Binary Cross Entropy Loss of 0.44567895328780194
# Training Complete with Binary Cross Entropy Loss of 0.4456611512238955
# Training Complete with Binary Cross Entropy Loss of 0.4364694975458327
# Training Complete with Binary Cross Entropy Loss of 0.4364941613459407
# Stopping Train at Iteration No.30
# Training Complete with Binary Cross Entropy Loss of 0.46294621445059314
# Stopping Train at Iteration No.81
# Training Complete with Binary Cross Entropy Loss of 0.46356289550832364
# Stopping Train at Iteration No.37
# Training Complete with Binary Cross Entropy Loss of 0.4540581596287611
# Training Complete with Binary Cross Entropy Loss of 0.45387257970348954
# Stopping Train at Iteration No.49
# Training Complete with Binary Cross Entropy Loss of 0.4451666144494203
# Training Complete with Binary Cross Entropy Loss of 0.4450143055374674
# Stopping Train at Iteration No.55
# Training Complete with Binary Cross Entropy Loss of 0.4419442804329159
# Training Complete with Binary Cross Entropy Loss of 0.44187389667274946
# Stopping Train at Iteration No.65
# Training Complete with Binary Cross Entropy Loss of 0.43809752814804176
# Training Complete with Binary Cross Entropy Loss of 0.438034189134806
# Stopping Train at Iteration No.56
# Training Complete with Binary Cross Entropy Loss of 0.4360400565235371
# Training Complete with Binary Cross Entropy Loss of 0.43588863224317087
# Stopping Train at Iteration No.28
# Training Complete with Binary Cross Entropy Loss of 0.4498383669399387
# Stopping Train at Iteration No.79
# Training Complete with Binary Cross Entropy Loss of 0.44973789413306325
# Stopping Train at Iteration No.34
# Training Complete with Binary Cross Entropy Loss of 0.44447312528991256
# Training Complete with Binary Cross Entropy Loss of 0.4445593056670936
# Stopping Train at Iteration No.42
# Training Complete with Binary Cross Entropy Loss of 0.4398383041524756
# Training Complete with Binary Cross Entropy Loss of 0.4398318354697013
# Stopping Train at Iteration No.46
# Training Complete with Binary Cross Entropy Loss of 0.4383651112600723
# Training Complete with Binary Cross Entropy Loss of 0.4382332249682264
# Stopping Train at Iteration No.51
# Training Complete with Binary Cross Entropy Loss of 0.4367016072448333
# Training Complete with Binary Cross Entropy Loss of 0.4365675086348639
# Stopping Train at Iteration No.39
# Training Complete with Binary Cross Entropy Loss of 0.4359560504418024
# Training Complete with Binary Cross Entropy Loss of 0.43585423067162826
# Stopping Train at Iteration No.25
# Training Complete with Binary Cross Entropy Loss of 0.44382259505195815
# Stopping Train at Iteration No.77
# Training Complete with Binary Cross Entropy Loss of 0.4438320573242301
# Stopping Train at Iteration No.31
# Training Complete with Binary Cross Entropy Loss of 0.4405580764822855
# Training Complete with Binary Cross Entropy Loss of 0.4407091419339842
# Stopping Train at Iteration No.37
# Training Complete with Binary Cross Entropy Loss of 0.43783538726684007
# Training Complete with Binary Cross Entropy Loss of 0.43775568481855265
# Stopping Train at Iteration No.40
# Training Complete with Binary Cross Entropy Loss of 0.4370884872154954
# Training Complete with Binary Cross Entropy Loss of 0.43699964885597786
# Stopping Train at Iteration No.40
# Training Complete with Binary Cross Entropy Loss of 0.4362378264028954
# Training Complete with Binary Cross Entropy Loss of 0.43609911682806873
# Stopping Train at Iteration No.30
# Training Complete with Binary Cross Entropy Loss of 0.43592376086366597
# Training Complete with Binary Cross Entropy Loss of 0.4358519913747023
# Stopping Train at Iteration No.23
# Training Complete with Binary Cross Entropy Loss of 0.44070579621325123
# Stopping Train at Iteration No.75
# Training Complete with Binary Cross Entropy Loss of 0.4406480787672949
# Stopping Train at Iteration No.28
# Training Complete with Binary Cross Entropy Loss of 0.4385926129529444
# Stopping Train at Iteration No.98
# Training Complete with Binary Cross Entropy Loss of 0.4385759974759997
# Stopping Train at Iteration No.32
# Training Complete with Binary Cross Entropy Loss of 0.43696590133794855
# Training Complete with Binary Cross Entropy Loss of 0.4369214112391675
# Stopping Train at Iteration No.34
# Training Complete with Binary Cross Entropy Loss of 0.4364997371034998
# Training Complete with Binary Cross Entropy Loss of 0.4364088094943729
# Stopping Train at Iteration No.32
# Training Complete with Binary Cross Entropy Loss of 0.4360788821387564
# Training Complete with Binary Cross Entropy Loss of 0.4359560191388857
# Stopping Train at Iteration No.25
# Training Complete with Binary Cross Entropy Loss of 0.4359000133165506
# Training Complete with Binary Cross Entropy Loss of 0.43585184930762266
# Stopping Train at Iteration No.32
# Training Complete with Binary Cross Entropy Loss of 0.6228191905051723
# Stopping Train at Iteration No.83
# Training Complete with Binary Cross Entropy Loss of 0.6131957242041092
# Stopping Train at Iteration No.43
# Training Complete with Binary Cross Entropy Loss of 0.5944470950198416
# Stopping Train at Iteration No.114
# Training Complete with Binary Cross Entropy Loss of 0.5964066329836918
# Stopping Train at Iteration No.63
# Training Complete with Binary Cross Entropy Loss of 0.5706380358904787
# Stopping Train at Iteration No.172
# Training Complete with Binary Cross Entropy Loss of 0.5692549527162223
# Stopping Train at Iteration No.77
# Training Complete with Binary Cross Entropy Loss of 0.553198111469099
# Training Complete with Binary Cross Entropy Loss of 0.5556719527370313
# Stopping Train at Iteration No.115
# Training Complete with Binary Cross Entropy Loss of 0.5196895393124239
# Training Complete with Binary Cross Entropy Loss of 0.5187974230546792
# Training Complete with Binary Cross Entropy Loss of 0.4488036624618269
# Training Complete with Binary Cross Entropy Loss of 0.4487020105908021
# Stopping Train at Iteration No.32
# Training Complete with Binary Cross Entropy Loss of 0.5023317199921647
# Stopping Train at Iteration No.84
# Training Complete with Binary Cross Entropy Loss of 0.5016571890720232
# Stopping Train at Iteration No.42
# Training Complete with Binary Cross Entropy Loss of 0.48434511697868077
# Stopping Train at Iteration No.112
# Training Complete with Binary Cross Entropy Loss of 0.4833778244843651
# Stopping Train at Iteration No.57
# Training Complete with Binary Cross Entropy Loss of 0.4650689331788573
# Stopping Train at Iteration No.166
# Training Complete with Binary Cross Entropy Loss of 0.46479658745674884
# Stopping Train at Iteration No.67
# Training Complete with Binary Cross Entropy Loss of 0.456881703112462
# Training Complete with Binary Cross Entropy Loss of 0.4568124448817052
# Stopping Train at Iteration No.88
# Training Complete with Binary Cross Entropy Loss of 0.4457471188581556
# Training Complete with Binary Cross Entropy Loss of 0.4454506556793411
# Stopping Train at Iteration No.105
# Training Complete with Binary Cross Entropy Loss of 0.4364297572281414
# Training Complete with Binary Cross Entropy Loss of 0.4360503421697462
# Stopping Train at Iteration No.30
# Training Complete with Binary Cross Entropy Loss of 0.4627450837782368
# Stopping Train at Iteration No.81
# Training Complete with Binary Cross Entropy Loss of 0.46302469596064355
# Stopping Train at Iteration No.37
# Training Complete with Binary Cross Entropy Loss of 0.4538512910280946
# Stopping Train at Iteration No.108
# Training Complete with Binary Cross Entropy Loss of 0.4535511047582139
# Stopping Train at Iteration No.49
# Training Complete with Binary Cross Entropy Loss of 0.44505530306172403
# Stopping Train at Iteration No.158
# Training Complete with Binary Cross Entropy Loss of 0.44506551331924454
# Stopping Train at Iteration No.55
# Training Complete with Binary Cross Entropy Loss of 0.4419745631228725
# Stopping Train at Iteration No.193
# Training Complete with Binary Cross Entropy Loss of 0.44176399375928055
# Stopping Train at Iteration No.66
# Training Complete with Binary Cross Entropy Loss of 0.43814657396821255
# Training Complete with Binary Cross Entropy Loss of 0.4379361948449315
# Stopping Train at Iteration No.57
# Training Complete with Binary Cross Entropy Loss of 0.43603643931353486
# Training Complete with Binary Cross Entropy Loss of 0.43585695013133524
# Stopping Train at Iteration No.27
# Training Complete with Binary Cross Entropy Loss of 0.44965249202949503
# Stopping Train at Iteration No.79
# Training Complete with Binary Cross Entropy Loss of 0.4497341872451598
# Stopping Train at Iteration No.34
# Training Complete with Binary Cross Entropy Loss of 0.4445116963223083
# Stopping Train at Iteration No.104
# Training Complete with Binary Cross Entropy Loss of 0.4443590078505313
# Stopping Train at Iteration No.42
# Training Complete with Binary Cross Entropy Loss of 0.43986568627374867
# Stopping Train at Iteration No.151
# Training Complete with Binary Cross Entropy Loss of 0.4397800569656329
# Stopping Train at Iteration No.46
# Training Complete with Binary Cross Entropy Loss of 0.43835691151999556
# Stopping Train at Iteration No.183
# Training Complete with Binary Cross Entropy Loss of 0.43816891460308116
# Stopping Train at Iteration No.50
# Training Complete with Binary Cross Entropy Loss of 0.4366689208778709
# Training Complete with Binary Cross Entropy Loss of 0.43654502846042065
# Stopping Train at Iteration No.39
# Training Complete with Binary Cross Entropy Loss of 0.43595489960254935
# Training Complete with Binary Cross Entropy Loss of 0.43585197857407254
# Stopping Train at Iteration No.25
# Training Complete with Binary Cross Entropy Loss of 0.4439135943965213
# Stopping Train at Iteration No.77
# Training Complete with Binary Cross Entropy Loss of 0.4436556356196551
# Stopping Train at Iteration No.31
# Training Complete with Binary Cross Entropy Loss of 0.44056283021172565
# Stopping Train at Iteration No.101
# Training Complete with Binary Cross Entropy Loss of 0.4405647376229936
# Stopping Train at Iteration No.37
# Training Complete with Binary Cross Entropy Loss of 0.43787154990957267
# Stopping Train at Iteration No.145
# Training Complete with Binary Cross Entropy Loss of 0.4377185616941462
# Stopping Train at Iteration No.40
# Training Complete with Binary Cross Entropy Loss of 0.4371023506867988
# Stopping Train at Iteration No.176
# Training Complete with Binary Cross Entropy Loss of 0.4369122757213632
# Stopping Train at Iteration No.40
# Training Complete with Binary Cross Entropy Loss of 0.4362652200030119
# Training Complete with Binary Cross Entropy Loss of 0.43609766284740503
# Stopping Train at Iteration No.30
# Training Complete with Binary Cross Entropy Loss of 0.43592287923398676
# Stopping Train at Iteration No.195
# Training Complete with Binary Cross Entropy Loss of 0.4358518435135504
# Stopping Train at Iteration No.23
# Training Complete with Binary Cross Entropy Loss of 0.44056694926529544
# Stopping Train at Iteration No.75
# Training Complete with Binary Cross Entropy Loss of 0.44067262162267645
# Stopping Train at Iteration No.28
# Training Complete with Binary Cross Entropy Loss of 0.4385565740857755
# Stopping Train at Iteration No.98
# Training Complete with Binary Cross Entropy Loss of 0.43862170038049036
# Stopping Train at Iteration No.33
# Training Complete with Binary Cross Entropy Loss of 0.4370336630409146
# Stopping Train at Iteration No.141
# Training Complete with Binary Cross Entropy Loss of 0.43688316854980874
# Stopping Train at Iteration No.34
# Training Complete with Binary Cross Entropy Loss of 0.4365130182841553
# Stopping Train at Iteration No.169
# Training Complete with Binary Cross Entropy Loss of 0.436402963839229
# Stopping Train at Iteration No.32
# Training Complete with Binary Cross Entropy Loss of 0.43607326617517583
# Training Complete with Binary Cross Entropy Loss of 0.4359450226421554
# Stopping Train at Iteration No.25
# Training Complete with Binary Cross Entropy Loss of 0.43589971089620916
# Stopping Train at Iteration No.126
# Training Complete with Binary Cross Entropy Loss of 0.43585184098365093
# Stopping Train at Iteration No.32
# Training Complete with Binary Cross Entropy Loss of 0.6194859039281974
# Stopping Train at Iteration No.84
# Training Complete with Binary Cross Entropy Loss of 0.615495371248531
# Stopping Train at Iteration No.43
# Training Complete with Binary Cross Entropy Loss of 0.5976812561572459
# Stopping Train at Iteration No.114
# Training Complete with Binary Cross Entropy Loss of 0.5978994400601456
# Stopping Train at Iteration No.63
# Training Complete with Binary Cross Entropy Loss of 0.5717751344663623
# Stopping Train at Iteration No.172
# Training Complete with Binary Cross Entropy Loss of 0.5705566509366323
# Stopping Train at Iteration No.77
# Training Complete with Binary Cross Entropy Loss of 0.5532560463519133
# Stopping Train at Iteration No.216
# Training Complete with Binary Cross Entropy Loss of 0.5552909218724702
# Stopping Train at Iteration No.115
# Training Complete with Binary Cross Entropy Loss of 0.5188998327481187
# Stopping Train at Iteration No.340
# Training Complete with Binary Cross Entropy Loss of 0.5195722943222569
# Stopping Train at Iteration No.300
# Training Complete with Binary Cross Entropy Loss of 0.44659060668321104
# Training Complete with Binary Cross Entropy Loss of 0.44601678701829595
# Stopping Train at Iteration No.32
# Training Complete with Binary Cross Entropy Loss of 0.5004972442480623
# Stopping Train at Iteration No.84
# Training Complete with Binary Cross Entropy Loss of 0.5001030468781105
# Stopping Train at Iteration No.41
# Training Complete with Binary Cross Entropy Loss of 0.4836210428940838
# Stopping Train at Iteration No.112
# Training Complete with Binary Cross Entropy Loss of 0.4833484933103383
# Stopping Train at Iteration No.57
# Training Complete with Binary Cross Entropy Loss of 0.46490607310673854
# Stopping Train at Iteration No.166
# Training Complete with Binary Cross Entropy Loss of 0.4644259615846443
# Stopping Train at Iteration No.67
# Training Complete with Binary Cross Entropy Loss of 0.45730391343218774
# Stopping Train at Iteration No.205
# Training Complete with Binary Cross Entropy Loss of 0.456895673320541
# Stopping Train at Iteration No.88
# Training Complete with Binary Cross Entropy Loss of 0.4458301431244047
# Stopping Train at Iteration No.312
# Training Complete with Binary Cross Entropy Loss of 0.44547257512346017
# Stopping Train at Iteration No.105
# Training Complete with Binary Cross Entropy Loss of 0.4364201351212922
# Training Complete with Binary Cross Entropy Loss of 0.4359723269920822
# Stopping Train at Iteration No.30
# Training Complete with Binary Cross Entropy Loss of 0.46296506179653285
# Stopping Train at Iteration No.81
# Training Complete with Binary Cross Entropy Loss of 0.46306027373434616
# Stopping Train at Iteration No.37
# Training Complete with Binary Cross Entropy Loss of 0.4538924602871374
# Stopping Train at Iteration No.108
# Training Complete with Binary Cross Entropy Loss of 0.45365018173401345
# Stopping Train at Iteration No.49
# Training Complete with Binary Cross Entropy Loss of 0.4451309902986833
# Stopping Train at Iteration No.158
# Training Complete with Binary Cross Entropy Loss of 0.4449620686829925
# Stopping Train at Iteration No.55
# Training Complete with Binary Cross Entropy Loss of 0.44194423690890133
# Stopping Train at Iteration No.193
# Training Complete with Binary Cross Entropy Loss of 0.44184791011774793
# Stopping Train at Iteration No.66
# Training Complete with Binary Cross Entropy Loss of 0.43826799285460655
# Stopping Train at Iteration No.288
# Training Complete with Binary Cross Entropy Loss of 0.43799267160289235
# Stopping Train at Iteration No.56
# Training Complete with Binary Cross Entropy Loss of 0.43603931842630284
# Training Complete with Binary Cross Entropy Loss of 0.43585360469103557
# Stopping Train at Iteration No.28
# Training Complete with Binary Cross Entropy Loss of 0.4499948695978543
# Stopping Train at Iteration No.79
# Training Complete with Binary Cross Entropy Loss of 0.4496847190902194
# Stopping Train at Iteration No.34
# Training Complete with Binary Cross Entropy Loss of 0.4446535650793979
# Stopping Train at Iteration No.105
# Training Complete with Binary Cross Entropy Loss of 0.44454743995188245
# Stopping Train at Iteration No.42
# Training Complete with Binary Cross Entropy Loss of 0.4398294537635516
# Stopping Train at Iteration No.151
# Training Complete with Binary Cross Entropy Loss of 0.439809035390488
# Stopping Train at Iteration No.46
# Training Complete with Binary Cross Entropy Loss of 0.43833779390159094
# Stopping Train at Iteration No.184
# Training Complete with Binary Cross Entropy Loss of 0.4382360707434177
# Stopping Train at Iteration No.50
# Training Complete with Binary Cross Entropy Loss of 0.4366971723435414
# Stopping Train at Iteration No.270
# Training Complete with Binary Cross Entropy Loss of 0.436540774957431
# Stopping Train at Iteration No.39
# Training Complete with Binary Cross Entropy Loss of 0.43595110489822503
# Stopping Train at Iteration No.370
# Training Complete with Binary Cross Entropy Loss of 0.43585187306974876
# Stopping Train at Iteration No.25
# Training Complete with Binary Cross Entropy Loss of 0.44380110407325224
# Stopping Train at Iteration No.77
# Training Complete with Binary Cross Entropy Loss of 0.4437286491435028
# Stopping Train at Iteration No.30
# Training Complete with Binary Cross Entropy Loss of 0.4404978244786917
# Stopping Train at Iteration No.101
# Training Complete with Binary Cross Entropy Loss of 0.4405837234180599
# Stopping Train at Iteration No.37
# Training Complete with Binary Cross Entropy Loss of 0.4378799656456975
# Stopping Train at Iteration No.145
# Training Complete with Binary Cross Entropy Loss of 0.43773277473313615
# Stopping Train at Iteration No.39
# Training Complete with Binary Cross Entropy Loss of 0.4370445575720461
# Stopping Train at Iteration No.176
# Training Complete with Binary Cross Entropy Loss of 0.4369983702602676
# Stopping Train at Iteration No.40
# Training Complete with Binary Cross Entropy Loss of 0.4362467540237009
# Stopping Train at Iteration No.254
# Training Complete with Binary Cross Entropy Loss of 0.43609546804721394
# Stopping Train at Iteration No.30
# Training Complete with Binary Cross Entropy Loss of 0.4359248464098194
# Stopping Train at Iteration No.192
# Training Complete with Binary Cross Entropy Loss of 0.4358518434116652
# Stopping Train at Iteration No.23
# Training Complete with Binary Cross Entropy Loss of 0.44067482943078845
# Stopping Train at Iteration No.75
# Training Complete with Binary Cross Entropy Loss of 0.44065875506085134
# Stopping Train at Iteration No.28
# Training Complete with Binary Cross Entropy Loss of 0.43857533676143723
# Stopping Train at Iteration No.98
# Training Complete with Binary Cross Entropy Loss of 0.43854951659745667
# Stopping Train at Iteration No.32
# Training Complete with Binary Cross Entropy Loss of 0.43696098043507464
# Stopping Train at Iteration No.141
# Training Complete with Binary Cross Entropy Loss of 0.4368531685164305
# Stopping Train at Iteration No.34
# Training Complete with Binary Cross Entropy Loss of 0.4365235139347031
# Stopping Train at Iteration No.170
# Training Complete with Binary Cross Entropy Loss of 0.4364308281754158
# Stopping Train at Iteration No.33
# Training Complete with Binary Cross Entropy Loss of 0.43607427289488876
# Stopping Train at Iteration No.240
# Training Complete with Binary Cross Entropy Loss of 0.43595456364449625
# Stopping Train at Iteration No.25
# Training Complete with Binary Cross Entropy Loss of 0.43589900695174677
# Stopping Train at Iteration No.125
# Training Complete with Binary Cross Entropy Loss of 0.43585184100877866
# Stopping Train at Iteration No.32
# Training Complete with Binary Cross Entropy Loss of 0.621712243751689
# Stopping Train at Iteration No.84
# Training Complete with Binary Cross Entropy Loss of 0.6217168577575446
# Stopping Train at Iteration No.43
# Training Complete with Binary Cross Entropy Loss of 0.5976637451580967
# Stopping Train at Iteration No.114
# Training Complete with Binary Cross Entropy Loss of 0.6004318012124245
# Stopping Train at Iteration No.63
# Training Complete with Binary Cross Entropy Loss of 0.570090468233658
# Stopping Train at Iteration No.173
# Training Complete with Binary Cross Entropy Loss of 0.572770801575852
# Stopping Train at Iteration No.78
# Training Complete with Binary Cross Entropy Loss of 0.5554943817563426
# Stopping Train at Iteration No.215
# Training Complete with Binary Cross Entropy Loss of 0.5534677451524421
# Stopping Train at Iteration No.116
# Training Complete with Binary Cross Entropy Loss of 0.5204895369543004
# Stopping Train at Iteration No.340
# Training Complete with Binary Cross Entropy Loss of 0.5190919491223818
# Stopping Train at Iteration No.302
# Training Complete with Binary Cross Entropy Loss of 0.4468836876110844
# Training Complete with Binary Cross Entropy Loss of 0.4458271069831405
# Stopping Train at Iteration No.32
# Training Complete with Binary Cross Entropy Loss of 0.5009333234710184
# Stopping Train at Iteration No.84
# Training Complete with Binary Cross Entropy Loss of 0.5002433750480948
# Stopping Train at Iteration No.42
# Training Complete with Binary Cross Entropy Loss of 0.48387364603307564
# Stopping Train at Iteration No.112
# Training Complete with Binary Cross Entropy Loss of 0.48386951536187367
# Stopping Train at Iteration No.57
# Training Complete with Binary Cross Entropy Loss of 0.46486025067239245
# Stopping Train at Iteration No.166
# Training Complete with Binary Cross Entropy Loss of 0.464983561723763
# Stopping Train at Iteration No.67
# Training Complete with Binary Cross Entropy Loss of 0.4572893961417376
# Stopping Train at Iteration No.205
# Training Complete with Binary Cross Entropy Loss of 0.45716025760772305
# Stopping Train at Iteration No.88
# Training Complete with Binary Cross Entropy Loss of 0.4458606618780392
# Stopping Train at Iteration No.312
# Training Complete with Binary Cross Entropy Loss of 0.4453676399342169
# Stopping Train at Iteration No.105
# Training Complete with Binary Cross Entropy Loss of 0.4364287637092903
# Training Complete with Binary Cross Entropy Loss of 0.435968762813717
# Stopping Train at Iteration No.30
# Training Complete with Binary Cross Entropy Loss of 0.462918303044488
# Stopping Train at Iteration No.81
# Training Complete with Binary Cross Entropy Loss of 0.4634161021589201
# Stopping Train at Iteration No.37
# Training Complete with Binary Cross Entropy Loss of 0.4539080092341483
# Stopping Train at Iteration No.108
# Training Complete with Binary Cross Entropy Loss of 0.4537522813993749
# Stopping Train at Iteration No.49
# Training Complete with Binary Cross Entropy Loss of 0.4450275354538867
# Stopping Train at Iteration No.158
# Training Complete with Binary Cross Entropy Loss of 0.44505670717245244
# Stopping Train at Iteration No.55
# Training Complete with Binary Cross Entropy Loss of 0.441920005447826
# Stopping Train at Iteration No.193
# Training Complete with Binary Cross Entropy Loss of 0.44195070231232836
# Stopping Train at Iteration No.65
# Training Complete with Binary Cross Entropy Loss of 0.4381124058334305
# Stopping Train at Iteration No.288
# Training Complete with Binary Cross Entropy Loss of 0.4380348591265411
# Stopping Train at Iteration No.57
# Training Complete with Binary Cross Entropy Loss of 0.4360350341646477
# Stopping Train at Iteration No.725
# Training Complete with Binary Cross Entropy Loss of 0.43585361941184575
# Stopping Train at Iteration No.27
# Training Complete with Binary Cross Entropy Loss of 0.4497908932805526
# Stopping Train at Iteration No.79
# Training Complete with Binary Cross Entropy Loss of 0.4495358123251604
# Stopping Train at Iteration No.34
# Training Complete with Binary Cross Entropy Loss of 0.4445379555948441
# Stopping Train at Iteration No.104
# Training Complete with Binary Cross Entropy Loss of 0.4443002971610207
# Stopping Train at Iteration No.42
# Training Complete with Binary Cross Entropy Loss of 0.4398955042932989
# Stopping Train at Iteration No.151
# Training Complete with Binary Cross Entropy Loss of 0.43975553128141226
# Stopping Train at Iteration No.46
# Training Complete with Binary Cross Entropy Loss of 0.4383018933176417
# Stopping Train at Iteration No.184
# Training Complete with Binary Cross Entropy Loss of 0.43829183147255424
# Stopping Train at Iteration No.51
# Training Complete with Binary Cross Entropy Loss of 0.4367307843692223
# Stopping Train at Iteration No.270
# Training Complete with Binary Cross Entropy Loss of 0.43654731205926717
# Stopping Train at Iteration No.39
# Training Complete with Binary Cross Entropy Loss of 0.43595876459104843
# Stopping Train at Iteration No.373
# Training Complete with Binary Cross Entropy Loss of 0.43585187380435664
# Stopping Train at Iteration No.25
# Training Complete with Binary Cross Entropy Loss of 0.4437618712362946
# Stopping Train at Iteration No.77
# Training Complete with Binary Cross Entropy Loss of 0.44373025628055274
# Stopping Train at Iteration No.30
# Training Complete with Binary Cross Entropy Loss of 0.4404905999505336
# Stopping Train at Iteration No.101
# Training Complete with Binary Cross Entropy Loss of 0.44039375900972527
# Stopping Train at Iteration No.37
# Training Complete with Binary Cross Entropy Loss of 0.4378479799669
# Stopping Train at Iteration No.146
# Training Complete with Binary Cross Entropy Loss of 0.4377581234093414
# Stopping Train at Iteration No.39
# Training Complete with Binary Cross Entropy Loss of 0.4370553095793401
# Stopping Train at Iteration No.176
# Training Complete with Binary Cross Entropy Loss of 0.43694801352731094
# Stopping Train at Iteration No.40
# Training Complete with Binary Cross Entropy Loss of 0.43624136183249995
# Stopping Train at Iteration No.255
# Training Complete with Binary Cross Entropy Loss of 0.4361164821400581
# Stopping Train at Iteration No.30
# Training Complete with Binary Cross Entropy Loss of 0.4359211041876201
# Stopping Train at Iteration No.192
# Training Complete with Binary Cross Entropy Loss of 0.4358518434008404
# Stopping Train at Iteration No.23
# Training Complete with Binary Cross Entropy Loss of 0.44072032156981794
# Stopping Train at Iteration No.75
# Training Complete with Binary Cross Entropy Loss of 0.44068419787282337
# Stopping Train at Iteration No.28
# Training Complete with Binary Cross Entropy Loss of 0.4385579349659995
# Stopping Train at Iteration No.98
# Training Complete with Binary Cross Entropy Loss of 0.43851783278978146
# Stopping Train at Iteration No.32
# Training Complete with Binary Cross Entropy Loss of 0.4369875105750739
# Stopping Train at Iteration No.141
# Training Complete with Binary Cross Entropy Loss of 0.43687847471305874
# Stopping Train at Iteration No.34
# Training Complete with Binary Cross Entropy Loss of 0.4365162895557736
# Stopping Train at Iteration No.169
# Training Complete with Binary Cross Entropy Loss of 0.4364014262219251
# Stopping Train at Iteration No.32
# Training Complete with Binary Cross Entropy Loss of 0.436071531624895
# Stopping Train at Iteration No.240
# Training Complete with Binary Cross Entropy Loss of 0.4359538625827338
# Stopping Train at Iteration No.25
# Training Complete with Binary Cross Entropy Loss of 0.43590068531944837
# Stopping Train at Iteration No.126
# Training Complete with Binary Cross Entropy Loss of 0.43585184096633806
# Best Score: 0.33170339990691144
# Best Hyperparameters: (200, 2.5, 0.9, 1e-05)

# %% [markdown]
# ## Train model with best hyperparameters
# Choose best hyper-parameters and create model with them

# %%
print(f"Hyper Parameters: {best_hyperparameters}")
max_iterations, learning_rate, decay, epsilon = best_hyperparameters

model = LogisticRegression(max_iterations, learning_rate, decay, epsilon)
# Out:
# Hyper Parameters: (200, 2.5, 0.9, 1e-05)

# %%
model.fit(X_train, Y_train)
# Out:
# Stopping Train at Iteration No.32
# Training Complete with Binary Cross Entropy Loss of 0.436938135832324

# %% [markdown]
# ## Predict results

# %%
Y_pred = model.predict(X_test)

# %% [markdown]
# ### Save Results as CSV file

# %%
result = pd.DataFrame({'PassengerId': testPassengerIds, 'Survived': Y_pred})

result.to_csv('output.csv', index=False)
